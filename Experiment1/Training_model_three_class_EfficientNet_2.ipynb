# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import keras
from numpy.random import randint
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from numpy.random import randint
from keras.models import Model
from keras.models import Input
from keras.layers import Dense
from keras.utils import np_utils
from keras.layers import Conv2D
from keras.layers import LeakyReLU
from keras.layers import Activation
import tensorflow as tf
import numpy as np
import sys
import matplotlib.pyplot as plt
from numpy import argmax
from keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelEncoder
import random
from tensorflow.keras.applications import EfficientNetB5
from tensorflow.keras import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import os

# %%
path_normal = '/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/train_test/train_normal/'
path_cap = '/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/train_test/train_cap/'
path_covid = '/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/train_test/train_covid/'

# %%
normal_image = []
cap_image = []
covid_image = []
normal_files = os.listdir(path_normal)
cap_files = os.listdir(path_cap)
covid_files = os.listdir(path_covid)

# %%
print('/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/normal/' + normal_files[0])
print(len(normal_files))
print(len(cap_files))
print(len(covid_files))
# Out:
# /content/drive/MyDrive/IndividualProject/SPGC-COVID/data/normal/normal034_97.jpg
# 8003
# 1323
# 6633

# %%
shuffled_indices_cap = np.random.permutation(len(cap_files))
shuffled_indices_covid = np.random.permutation(len(covid_files))
shuffled_indices_normal = np.random.permutation(len(normal_files))
indices_cap = shuffled_indices_cap[: 900]
indices_covid = shuffled_indices_covid[: 900]
indices_normal = shuffled_indices_normal[: 900]
print(indices_cap[0], len(indices_cap))
print(indices_covid[0], len(indices_covid))
print(indices_normal[0], len(indices_normal))
# Out:
# 327 900
# 5223 900
# 3993 900

# %%
count = 0
for idx in indices_normal:
  file = normal_files[idx]
  count = count + 1
  if count % 200 == 0:
    print(count)
  temp = path_normal + file
  img = cv2.imread(temp)
  img = np.array(img)
  img = (img/255).astype("float32")
  normal_image.append(img)
del indices_normal
del normal_files
print(len(normal_image))

count = 0
for idx in indices_cap:
  file = cap_files[idx]
  count = count + 1
  if count % 200 == 0:
    print(count)
  temp = path_cap + file
  img = cv2.imread(temp)
  img = np.array(img)
  img = (img/255).astype("float32")
  cap_image.append(img)
del indices_cap
del cap_files
print(len(cap_image))

count = 0
for idx in indices_covid:
  count = count + 1
  file = covid_files[idx]
  if count % 200 == 0:
    print(count)
  temp = path_covid + file
  img = cv2.imread(temp)
  img = np.array(img)
  img = (img/255).astype("float32")
  covid_image.append(img)
del indices_covid
del covid_files
print(len(covid_image))
# Out:
# 200
# 400
# 600
# 800
# 900
# 200
# 400
# 600
# 800
# 900
# 200
# 400
# 600
# 800
# 900

# %%
X = []
Y = []
for img in normal_image:
  X.append(img)
  Y.append([1, 0, 0])
del normal_image

for img in cap_image:
  X.append(img)
  Y.append([0, 1, 0])
del cap_image

for img in covid_image:
  X.append(img)
  Y.append([0, 0, 1])
del covid_image

np.random.seed(200)
np.random.shuffle(X) 
np.random.seed(200)
np.random.shuffle(Y)

# %%
datagen1 = ImageDataGenerator(featurewise_center=True)
datagen1.fit(X)
mean = datagen1.mean
X = X-mean
print("mean value",mean)
del mean
X = np.reshape(X, (len(X),512,512,3))
print(X.shape)
Y = np.array(Y)
# Out:
# mean value [[[0.0237037 0.0237037 0.0237037]]]
# (2700, 512, 512, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model1 = Sequential([
    EfficientNetB5(include_top=False, weights='imagenet', input_shape=(512,512,3)),
    tf.keras.layers.GlobalAveragePooling2D(),
    Dense(1024,activation='tanh'),
    Dense(3, activation='softmax')
])
model1.build(input_shape=(None, 512,512,3))
model1.summary()
model1.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001, beta_1=0.5, decay=5e-2), metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115269632/115263384 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnetb5 (Functional)  (None, 16, 16, 2048)      28513527
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# module_wrapper (ModuleWrappe (None, 1024)              2098176
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 3)                 3075
# =================================================================
# Total params: 30,614,778
# Trainable params: 30,442,035
# Non-trainable params: 172,743
# _________________________________________________________________

# %%
model1.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    batch_size=10,
    epochs=10,
    shuffle=True,
)
# Out:
# Epoch 1/10
# 216/216 [==============================] - 1813s 8s/step - loss: 0.5654 - accuracy: 0.7671 - val_loss: 1.1029 - val_accuracy: 0.3500
# Epoch 2/10
# 216/216 [==============================] - 1670s 8s/step - loss: 0.3279 - accuracy: 0.8866 - val_loss: 1.2197 - val_accuracy: 0.3519
# Epoch 3/10
# 216/216 [==============================] - 1679s 8s/step - loss: 0.2795 - accuracy: 0.8921 - val_loss: 1.1699 - val_accuracy: 0.3648
# Epoch 4/10
# 216/216 [==============================] - 1657s 8s/step - loss: 0.2688 - accuracy: 0.9014 - val_loss: 0.7062 - val_accuracy: 0.6815
# Epoch 5/10
# 216/216 [==============================] - 1655s 8s/step - loss: 0.2227 - accuracy: 0.9250 - val_loss: 0.2418 - val_accuracy: 0.9111
# Epoch 6/10
# 216/216 [==============================] - 1692s 8s/step - loss: 0.2178 - accuracy: 0.9222 - val_loss: 0.3405 - val_accuracy: 0.8537
# Epoch 7/10
# 216/216 [==============================] - 1678s 8s/step - loss: 0.2132 - accuracy: 0.9282 - val_loss: 0.2100 - val_accuracy: 0.9204
# Epoch 8/10
# 216/216 [==============================] - 1687s 8s/step - loss: 0.2154 - accuracy: 0.9222 - val_loss: 0.3269 - val_accuracy: 0.8704
# Epoch 9/10
# 216/216 [==============================] - 1718s 8s/step - loss: 0.1837 - accuracy: 0.9407 - val_loss: 0.2067 - val_accuracy: 0.9167
# Epoch 10/10
# 216/216 [==============================] - 1690s 8s/step - loss: 0.1904 - accuracy: 0.9338 - val_loss: 0.1902 - val_accuracy: 0.9259

# %%
model1.save_weights("/content/drive/MyDrive/IndividualProject/SPGC-COVID/Baseline_Efficient_2/Baseline_Efficient_2.ckpt")
