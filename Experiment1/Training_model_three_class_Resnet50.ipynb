# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import os
import keras
from numpy.random import randint
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.models import Model
from keras.models import Input
from keras.layers import Conv2D
from keras.layers import LeakyReLU
from keras.layers import Activation
import tensorflow as tf
import numpy as np
import sys
from numpy import argmax
from keras.preprocessing.image import ImageDataGenerator
import random
from tensorflow.keras import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import os
from keras.applications.resnet_v2 import ResNet50V2
from keras.layers import Dense

# %%
path_normal = '/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/train_test/train_normal/'
path_cap = '/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/train_test/train_cap/'
path_covid = '/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/train_test/train_covid/'

# %%
normal_image = []
cap_image = []
covid_image = []
normal_files = os.listdir(path_normal)
cap_files = os.listdir(path_cap)
covid_files = os.listdir(path_covid)

# %%
print('/content/drive/MyDrive/IndividualProject/SPGC-COVID/data/normal/' + normal_files[0])
print(len(normal_files))
print(len(cap_files))
print(len(covid_files))
# Out:
# /content/drive/MyDrive/IndividualProject/SPGC-COVID/data/normal/normal034_97.jpg
# 8003
# 1323
# 6633

# %%
shuffled_indices_cap = np.random.permutation(len(cap_files))
shuffled_indices_covid = np.random.permutation(len(covid_files))
shuffled_indices_normal = np.random.permutation(len(normal_files))
indices_cap = shuffled_indices_cap[: 900]
indices_covid = shuffled_indices_covid[: 900]
indices_normal = shuffled_indices_normal[: 900]
print(indices_cap[0], len(indices_cap))
print(indices_covid[0], len(indices_covid))
print(indices_normal[0], len(indices_normal))
# Out:
# 529 900
# 5379 900
# 7870 900

# %%
count = 0
for idx in indices_normal:
  file = normal_files[idx]
  count = count + 1
  if count % 200 == 0:
    print(count)
  temp = path_normal + file
  img = cv2.imread(temp)
  img = np.array(img)
  img = (img/255).astype("float32")
  normal_image.append(img)
indices_normal = None
normal_files = None
print(len(normal_image))

count = 0
for idx in indices_cap:
  file = cap_files[idx]
  count = count + 1
  if count % 200 == 0:
    print(count)
  temp = path_cap + file
  img = cv2.imread(temp)
  img = np.array(img)
  img = (img/255).astype("float32")
  cap_image.append(img)
indices_cap = None
cap_files = None
print(len(cap_image))

count = 0
for idx in indices_covid:
  count = count + 1
  file = covid_files[idx]
  if count % 200 == 0:
    print(count)
  temp = path_covid + file
  img = cv2.imread(temp)
  img = np.array(img)
  img = (img/255).astype("float32")
  covid_image.append(img)
indices_covid = None
covid_files = None
print(len(covid_image))
# Out:
# 200
# 400
# 600
# 800
# 900
# 200
# 400
# 600
# 800
# 900
# 200
# 400
# 600
# 800
# 900

# %%
X = []
Y = []
for img in normal_image:
  X.append(img)
  Y.append([1, 0, 0])
normal_image = None

for img in cap_image:
  X.append(img)
  Y.append([0, 1, 0])
cap_img = None

for img in covid_image:
  X.append(img)
  Y.append([0, 0, 1])
covid_image = None

np.random.seed(200)
np.random.shuffle(X) 
np.random.seed(200)
np.random.shuffle(Y)

# %%
datagen1 = ImageDataGenerator(featurewise_center=True)
datagen1.fit(X)
mean = datagen1.mean
X = X-mean
print("mean value",mean)
mean = None
X = np.reshape(X, (len(X),512,512,3))
print(X.shape)
Y = np.array(Y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model1 = Sequential([
    ResNet50V2(include_top=False, weights='imagenet', input_shape=(512,512,3)),
    tf.keras.layers.GlobalAveragePooling2D(),
    Dense(1024,activation='tanh'),
    Dense(3, activation='softmax')
])
model1.build(input_shape=(None, 512,512,3))
model1.summary()
model1.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001, beta_1=0.5, decay=5e-2), metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper (ModuleWrappe (None, 16, 16, 2048)      23564800
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 1024)              2098176
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 3)                 3075
# =================================================================
# Total params: 25,666,051
# Trainable params: 25,620,611
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
model1.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    batch_size=10,
    epochs=10,
    shuffle=True,
)
# Out:
# Epoch 1/10
# 216/216 [==============================] - 944s 4s/step - loss: 0.4418 - accuracy: 0.8208 - val_loss: 0.4182 - val_accuracy: 0.8389
# Epoch 2/10
# 216/216 [==============================] - 943s 4s/step - loss: 0.1211 - accuracy: 0.9741 - val_loss: 0.3428 - val_accuracy: 0.8759
# Epoch 3/10
# 216/216 [==============================] - 793s 4s/step - loss: 0.0785 - accuracy: 0.9856 - val_loss: 0.3166 - val_accuracy: 0.8722
# Epoch 4/10
# 216/216 [==============================] - 807s 4s/step - loss: 0.0576 - accuracy: 0.9926 - val_loss: 0.1612 - val_accuracy: 0.9315
# Epoch 5/10
# 216/216 [==============================] - 783s 4s/step - loss: 0.0452 - accuracy: 0.9963 - val_loss: 0.1187 - val_accuracy: 0.9648
# Epoch 6/10
# 216/216 [==============================] - 770s 4s/step - loss: 0.0380 - accuracy: 0.9949 - val_loss: 0.1143 - val_accuracy: 0.9648
# Epoch 7/10
# 216/216 [==============================] - 787s 4s/step - loss: 0.0320 - accuracy: 0.9981 - val_loss: 0.1090 - val_accuracy: 0.9648
# Epoch 8/10
# 216/216 [==============================] - 768s 4s/step - loss: 0.0289 - accuracy: 0.9977 - val_loss: 0.1063 - val_accuracy: 0.9630
# Epoch 9/10
# 216/216 [==============================] - 759s 4s/step - loss: 0.0267 - accuracy: 0.9977 - val_loss: 0.1096 - val_accuracy: 0.9685
# Epoch 10/10
# 216/216 [==============================] - 776s 4s/step - loss: 0.0265 - accuracy: 0.9963 - val_loss: 0.1055 - val_accuracy: 0.9648

# %%
model1.save_weights("/content/drive/MyDrive/IndividualProject/SPGC-COVID/Final_ResNet50V2_three_class_2/Final_ResNet50V2_three_class_2.ckpt")
